# %%
# %load_ext jupyter_ai_magics
# Out:
# D:\ds\work\workspace\git\dsp-ai-control-tower\.jl_venv\Lib\site-packages\google\cloud\aiplatform\models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils

# %%
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# bedrock
# * bedrock:amazon.titan-text-express-v1
# * bedrock:amazon.titan-text-lite-v1
# * bedrock:amazon.titan-text-premier-v1:0
# * bedrock:ai21.j2-ultra-v1
# * bedrock:ai21.j2-mid-v1
# * bedrock:ai21.jamba-instruct-v1:0
# * bedrock:cohere.command-light-text-v14
# * bedrock:cohere.command-text-v14
# * bedrock:cohere.command-r-v1:0
# * bedrock:cohere.command-r-plus-v1:0
# * bedrock:meta.llama2-13b-chat-v1
# * bedrock:meta.llama2-70b-chat-v1
# * bedrock:meta.llama3-8b-instruct-v1:0
# * bedrock:meta.llama3-70b-instruct-v1:0
# * bedrock:meta.llama3-1-8b-instruct-v1:0
# * bedrock:meta.llama3-1-70b-instruct-v1:0
# * bedrock:meta.llama3-1-405b-instruct-v1:0
# * bedrock:mistral.mistral-7b-instruct-v0:2
# ...

# %%
# %env OPENROUTER_API_KEY=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
# %env OPENROUTER_API_BASE=https://integrate.api.nvidia.com/v1
# Out:
# env: OPENROUTER_API_KEY=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
# env: OPENROUTER_API_BASE=https://integrate.api.nvidia.com/v1

# %%
get_ipython().run_cell_magic('ai', 'openrouter:meta/llama-3.3-70b-instruct -f code', 'Generate a pandas dataframe to depict airport delay times\n')
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_ipython().run_cell_magic('ai', 'openrouter:meta/llama-3.3-70b-instruct -f code', 'Generate a pandas dataframe to depict airport delay times\n')
#
# File D:\ds\work\workspace\git\dsp-ai-control-tower\.jl_venv\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
# %%ai openrouter:meta/llama-3.3-70b-instruct -f code
# Generate a pandas dataframe to depict airport delay times
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 get_ipython().run_cell_magic('ai', 'openrouter:* -f code', 'Generate a pandas dataframe to depict airport delay times\n')
#
# File D:\ds\work\workspace\git\dsp-ai-control-tower\.jl_venv\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...
